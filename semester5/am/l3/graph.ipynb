# %%
import matplotlib.pyplot as plt

def visualise_graph(points, filename):
    x, y = zip(*points)
    plt.scatter(x, y, c='blue', marker='o', label='Points', s=15)

    for i in range(len(points) - 1):
        plt.plot([points[i][0], points[i + 1][0]], [points[i][1], points[i + 1][1]], c='red', linestyle='-', linewidth=1)

    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Wizualizacja sciezki dla ' + filename.split('/')[1].split('.')[0])

    plt.savefig(filename)
    plt.show()

# %%
def read_file(filename):
    with open(filename, 'r') as file:
        tsp_length = int(file.readline())
        points = []
        for line in file:
            point = line.split()
            points.append((int(point[0]), int(point[1])))
        points.append(points[0])
    return tsp_length,points

# %%
def calc_len(points):
    length = 0
    for i in range(len(points) - 1):
        length += int(((points[i][0] - points[i + 1][0]) ** 2 + (points[i][1] - points[i + 1][1]) ** 2) ** 0.5)
    length += int(((points[-1][0] - points[0][0]) ** 2 + (points[-1][1] - points[0][1]) ** 2) ** 0.5)
    return length

# %%
import os

# get all files in directory './data'
filenames = []
for filename in os.listdir('./data'):
    filenames.append('./output_' + filename)

for filename in filenames:
    print(filename)
    length, points = read_file(filename)
    print(calc_len(points))
    visualise_graph(points, f'plots/{filename.split("_")[1]}.png')
# Out:
# ./output_pbn423.tsp
# 1770
# ./output_xqf131.tsp
# 572
# ./output_pma343.tsp
# 1620
# ./output_icw1483.tsp
# 7231
# ./output_xql662.tsp
# 3544
# ./output_bcl380.tsp
# 2005
# ./output_pbl395.tsp
# 1611
# ./output_pds2566.tsp
# 13972
# ./output_pbm436.tsp
# 1898
# ./output_djc1785.tsp
# 10245
# ./output_xqg237.tsp
# 1070
# ./output_pka379.tsp
# 1550
# ./output_pbk411.tsp
# 1743
# ./output_dcb2086.tsp
# 11489
# ./output_xit1083.tsp
# 5726
