# %%
import numpy as np
import matplotlib.pyplot as plt
#1158

x = [i for i in np.arange(0.0, 1.4, 0.1)]
y = [1159.3, 1160.1, 1159.7, 1162.6, 1159.2, 1159.1, 1159.1, 1159.1,
     1159.1, 1159.1, 1159.1, 1159.1, 1159.1, 1159.1]

plt.figure(figsize=(8, 6))

plt.plot(x, y, marker='o', linestyle='-', color='blue')

plt.title(r'Wpływ współczynnika temperatury na średni wynik xqg237 $(T=xN)$')
plt.xlabel('alpha')
plt.ylabel('średnia waga rozwiązania')

plt.grid(True)
plt.show()
