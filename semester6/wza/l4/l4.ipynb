# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0, 2*np.pi, 10000)

r = np.abs(np.sin(2 * theta))

plt.figure(figsize=(6,6))
plt.polar(theta, r)

plt.title(r"$r(\theta) = \sin(2\theta)$")

plt.show()
