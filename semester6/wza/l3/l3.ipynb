# %% [markdown]
# ### Podpunkt 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)

X, Y = np.meshgrid(x, y)

Z = X**2 + Y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title(r'V($z - x^2 - y^2$)')

plt.show()

# %% [markdown]
# ### Podpunkt 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)

X, Y = np.meshgrid(x, y)

Z_pos = np.sqrt(X**2 + Y**2)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z_pos, cmap='viridis')

Z_neg = -np.sqrt(X**2 + Y**2)

ax.plot_surface(X, Y, Z_neg, cmap='viridis')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title(r'V($z^2 - x^2 - y^2$)')

plt.show()

# %% [markdown]
# ### Podpunkt 3

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)

X, Y = np.meshgrid(x, y)

Z = X**2 - Y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title(r'V($z - x^2 + y^2$)')

plt.show()

# %% [markdown]
# ### Podpunkt 4

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

z = np.linspace(-2, 2, 100)
y = np.zeros(len(x))
x = 0 * z

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z, color='black')

x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x, y)
Z = 0 * X

ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title(r'V($xz, yz$)')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 11
#       9 fig = plt.figure()
#      10 ax = fig.add_subplot(111, projection='3d')
# ---> 11 ax.plot(x, y, z, color='black')
#      13 x = np.linspace(-2, 2, 100)
#      14 y = np.linspace(-2, 2, 100)
#
# File ~/.local/lib/python3.11/site-packages/mpl_toolkits/mplot3d/axes3d.py:1485, in Axes3D.plot(self, xs, ys, zdir, *args, **kwargs)
#    1482     zs = kwargs.pop('zs', 0)
#    1484 # Match length
# -> 1485 zs = np.broadcast_to(zs, np.shape(xs))
#    1487 lines = super().plot(xs, ys, *args, **kwargs)
#    1488 for line in lines:
#
# File <__array_function__ internals>:200, in broadcast_to(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/numpy/lib/stride_tricks.py:413, in broadcast_to(array, shape, subok)
#     367 @array_function_dispatch(_broadcast_to_dispatcher, module='numpy')
#     368 def broadcast_to(array, shape, subok=False):
#     369     """Broadcast an array to a new shape.
#     370
#     371     Parameters
#    (...)
#     411            [1, 2, 3]])
#     412     """
# --> 413     return _broadcast_to(array, shape, subok=subok, readonly=True)
#
# File ~/.local/lib/python3.11/site-packages/numpy/lib/stride_tricks.py:344, in _broadcast_to(array, shape, subok, readonly)
#     342 array = np.array(array, copy=False, subok=subok)
#     343 if not shape and array.shape:
# --> 344     raise ValueError('cannot broadcast a non-scalar to a scalar array')
#     345 if any(size < 0 for size in shape):
#     346     raise ValueError('all elements of broadcast shape must be non-'
#     347                      'negative')
#
# ValueError: cannot broadcast a non-scalar to a scalar array
